# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
db.list_collection_names()
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %%
establishments.find_one()
# Out:
# {'_id': ObjectId('64bd495a2b17a5809aca5e38'),
#  'FHRSID': 289560,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000039927',
#  'BusinessName': 'Mariner',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'AddressLine1': '16 The Stade',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'PostCode': 'CT19 6AB',
#  'Phone': '',
#  'RatingValue': 5,
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2019-03-19T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 1.188537, 'latitude': 51.08084},
#  'RightToReply': '',
#  'Distance': 4591.912144538092,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
# ...

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {"scores.Hygiene" : 20}
fields = {"BusinessName": 1}
results = list(establishments.find(query,fields))

for result in results:
    pprint(result)

# Use count_documents to display the number of documents in the result
print (len(results))

print("\n \n Number of documents using count_documents function\n \n ", establishments.count_documents(query))
# Display the first document in the results using pprint
print(results[0])
# Out:
# {'BusinessName': 'The Chase Rest Home',
#  '_id': ObjectId('64bd495b2b17a5809aca7967')}
# {'BusinessName': 'Brenalwood', '_id': ObjectId('64bd495b2b17a5809aca7ce8')}
# {'BusinessName': 'Melrose Hotel', '_id': ObjectId('64bd495b2b17a5809aca7ff8')}
# {'BusinessName': 'Seaford Pizza', '_id': ObjectId('64bd495b2b17a5809aca81e0')}
# {'BusinessName': 'Golden Palace', '_id': ObjectId('64bd495b2b17a5809aca81f1')}
# {'BusinessName': "Ashby's Butchers",
#  '_id': ObjectId('64bd495b2b17a5809aca8b8d')}
# {'BusinessName': 'South Sea Express Cuisine',
#  '_id': ObjectId('64bd495b2b17a5809aca8db0')}
# {'BusinessName': 'Golden Palace', '_id': ObjectId('64bd495b2b17a5809acaa2da')}
# {'BusinessName': 'The Tulip Tree', '_id': ObjectId('64bd495b2b17a5809acaa71f')}
# {'BusinessName': 'F & S', '_id': ObjectId('64bd495b2b17a5809acaaf32')}
# {'BusinessName': 'Longhouse', '_id': ObjectId('64bd495b2b17a5809acaafa0')}
# {'BusinessName': 'Westview Playgroup Based At Downsview Comm Primary',
# ...

# %%
# Display the first document in the results using pprint

result1 = establishments.find(query)
pprint(result1[0])
# Out:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64bd495b2b17a5809aca7967'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
# ...

# %%
# Convert the result to a Pandas DataFrame
result_df = pd.DataFrame(result1)

# Display the number of rows in the DataFrame
len(result_df)

# Display the first 10 rows of the DataFrame
result_df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  64bd495b2b17a5809aca7967   110681                  0
# 1  64bd495b2b17a5809aca7ce8   612039                  0
# 2  64bd495b2b17a5809aca7ff8   730933                  0
# 3  64bd495b2b17a5809aca81e0   172735                  0
# 4  64bd495b2b17a5809aca81f1   172953                  0
# 5  64bd495b2b17a5809aca8b8d   512854                  0
# 6  64bd495b2b17a5809aca8db0  1537089                  0
# 7  64bd495b2b17a5809acaa2da   155648                  0
# 8  64bd495b2b17a5809acaa71f  1012883                  0
# 9  64bd495b2b17a5809acaaf32   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {"LocalAuthorityName" : {"$regex" : "London"}, "RatingValue" : {'$gte':4}}

result_london = list(establishments.find(query))

print(len(result_london),"\n \n")

for i in range(4):
    pprint(result_london[i])



# Use count_documents to display the number of documents in the result
print("\n\n  NUMBER OF DOCUMENTS ARE : ",establishments.count_documents(query))
# Out:
# 33
#
#
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64bd495b2b17a5809aca9382'),
#  'geocode': {'latitude': 51.369321, 'longitude': 0.508551},
# ...

# %%
# Display the first document in the results using pprint
pprint(result_london[0])
# Out:
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64bd495b2b17a5809aca9382'),
#  'geocode': {'latitude': 51.369321, 'longitude': 0.508551},
# ...

# %%
# Convert the result to a Pandas DataFrame
london_df = pd.json_normalize(result_london)


# Display the number of rows in the DataFrame
print(len(london_df))
# Display the first 10 rows of the DataFrame
london_df.head(10)
# Out:
# 33
#                         _id   FHRSID  ChangesByServerID  \
# 0  64bd495b2b17a5809aca9382   621707                  0
# 1  64bd495b2b17a5809aca96a8  1130836                  0
# 2  64bd495b2b17a5809acaa1f7   293783                  0
# 3  64bd495b2b17a5809acaaff5  1315095                  0
# 4  64bd495b2b17a5809acaaff7   294474                  0
# 5  64bd495b2b17a5809acab700   294900                  0
# 6  64bd495b2b17a5809acad80d   293756                  0
# 7  64bd495b2b17a5809acadbd4   878523                  0
# 8  64bd495b2b17a5809acadbed   293772                  0
# 9  64bd495b2b17a5809acadbee   294606                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000036464  Coombs Catering t/a The Lock and Key
# ...

# %%
#Find the latitude and longitude for Pengang Flavours
query = {'BusinessName':"Penang Flavours"}
fields = {'BusinessName':1, 'geocode.latitude':1, 'geocode.longitude':1}

# Cast the results as a list and save the results to a variable
results = list(establishments.find(query, fields))

# Pretty print the results


pprint(results)
# Out:
# [{'BusinessName': 'Penang Flavours',
#   '_id': ObjectId('64bd496af8acd70f8592c730'),
#   'geocode': {'latitude': 51.490142, 'longitude': 0.08384}}]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score



#LONGITUDE - MAKING CODE TO AUTOMATIC CALCULATE LONGITUDE AND LATTIUDE VIA DEGREE SEARCH 
# x = input ("enter degree search")
degree_search = 0.01


geocodel = [i["geocode"] for i in results]
# print(geocode)
latitude_value = [lat["latitude"] for lat in geocodel]
# print(longitude_value)
latitude= latitude_value[0]
latitude=float(latitude)
print(latitude)
x = latitude - degree_search
x1 = latitude + degree_search
print(x, x1)
print(type(x))

geocode = [j["geocode"] for j in results]
# print(geocode)
longitude_value = [long["longitude"] for long in geocode]
# print(longitude_value)
longitude= longitude_value[0]
longitude=float(longitude)
print(longitude)
y=longitude-degree_search
y1 = longitude + degree_search
print (y, y1)

query12 = {'RatingValue': 5, 'geocode.latitude':{'$lte': x1, '$gte': x },'geocode.longitude':{'$lte': y1, '$gte': y } }


sort = [("score.Hygiene", 1)] #1 ascending order

limit = 5

# Print the results
results_rest = list(establishments.find(query12).sort(sort).limit(limit))

results_rest
# Print the results
# for result in results_rest:
#     print(results_rest)
# Out:
# 51.490142
# 51.480142 51.500142
# <class 'float'>
# 0.08384
# 0.07384 0.09383999999999999
# [{'_id': ObjectId('64bd495b2b17a5809acad1c7'),
#   'FHRSID': 694609,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000116619',
#   'BusinessName': 'Volunteer',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': '130 - 132 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'PostCode': 'SE18 1JQ',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-08-05T00:00:00',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 0.09208, 'latitude': 51.4873437},
# ...

# %%
# Convert result to Pandas DataFrame
penang_df = pd.DataFrame(results_rest)
penang_df
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  64bd495b2b17a5809acad1c7   694609                  0
# 1  64bd495b2b17a5809acad1e0   695241                  0
# 2  64bd495b2b17a5809acad19b   695223                  0
# 3  64bd495b2b17a5809acad17e  1069652                  0
# 4  64bd495b2b17a5809acad1aa  1380578                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0             PI/000116619                            Volunteer
# 1             PI/000179088              Plumstead Manor Nursery
# 2             PI/000178842                              Iceland
# 3             PI/000206841   TIWA N TIWA African Restaurant Ltd
# 4                    14425  Howe and Co Fish and Chips - Van 17
#
#                             BusinessType  BusinessTypeID  \
# 0                      Pub/bar/nightclub            7843
# 1                        Caring Premises               5
# 2  Retailers - supermarkets/hypermarkets            7840
# ...

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.490142
longitude = 0.08384 

query = {
        'geocode.latitude':{
        '$gte': latitude-degree_search,
        '$lte': latitude+degree_search
    },
    'geocode.longitude': {
        '$gte': longitude-degree_search,
        '$lte': longitude+degree_search
    }
}
sort = [('score.Hygiene',1)] #ascending order
limit = 5

#Cast the results as a list and save them to a variable
results = list(establishments.find(query))
# Print the results
pprint(results)
# Out:
# [{'AddressLine1': '152 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'TIWA N TIWA African Restaurant Ltd',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4646.930146257832,
#   'FHRSID': 1069652,
#   'LocalAuthorityBusinessID': 'PI/000206841',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2020-10-24T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64bd495b2b17a5809acad17e'),
#   'geocode': {'latitude': 51.4870351, 'longitude': 0.0927429},
# ...

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0

match_query = {'$match': {'scores.Hygiene': 0 }
              }
# 2. Groups the matches by Local Authority
group_query = {'$group': {'_id': "$LocalAuthorityName", 
                          'count': { '$sum': 1 }
                         }
              }
# 3. Sorts the matches from highest to lowest
sort_values = {'$sort': { 'count': -1 }}

# Put the pipeline together
pipeline = [match_query, group_query, sort_values]
# Run the pipeline through the aggregate method, cast the results as a list, and save the results to a variable
results_group = list(establishments.aggregate(pipeline))
# Print the first 10 results
pprint(results_group[0:10])
# Out:
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
pipeline_df = pd.DataFrame(results_group)
# Display the number of rows in the DataFrame
print("Number of rows:", len(pipeline_df))
# Display the first 10 rows of the DataFrame
pipeline_df.head(10)
# Out:
# Number of rows: 55
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
